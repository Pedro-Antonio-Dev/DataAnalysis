# %% [markdown]
# ### Exercício 16: Insira valores nulos e identifique-os.

# %%
import pandas as pd

# %%
dataframe = pd.read_csv("dados/produtos.csv")
dataframe
# Out:
#    ID       Produto    Categoria   Preco  Quantidade
# 0   1      Notebook  Eletrônicos  3500.0         5.0
# 1   2         Mouse  Eletrônicos    80.0        30.0
# 2   3       Teclado  Eletrônicos   150.0        20.0
# 3   4       Cadeira       Móveis   600.0        10.0
# 4   5          Mesa       Móveis   900.0         7.0
# 5   6  Livro Python       Livros   120.0        15.0
# 6   7     Livro SQL       Livros   100.0        12.0
# 7   8           NaN          NaN     NaN         NaN
# 8   9           NaN          NaN     NaN         NaN

# %%
dataframe.dtypes
# Out:
# ID              int64
# Produto           str
# Categoria         str
# Preco         float64
# Quantidade    float64
# dtype: object

# %%
valores_nulos = dataframe.isnull().sum()
valores_nulos
# Out:
# ID            0
# Produto       2
# Categoria     2
# Preco         2
# Quantidade    2
# dtype: int64
