# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.4.2'

# %%
arr = np.array([1, 2, 3, 4, 5])

# %%
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
soma = arr + 10
print(soma)
# Out:
# [11 12 13 14 15]

# %%
multi = arr * 2
print(multi)
# Out:
# [ 2  4  6  8 10]

# %%
media = np.mean(arr)
print(media)
# Out:
# 3.0
