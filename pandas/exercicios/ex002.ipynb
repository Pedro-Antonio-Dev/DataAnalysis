# %%
import pandas as pd
import json

# %%
dados = {
    "loja": "TechStore",
    "data_exportacao": "2026-05-25",
    "produtos": [
        {
            "id": 1,
            "nome": "Notebook Gamer",
            "categoria": "Eletronicos",
            "preco": 4500.90,
            "estoque": 12,
            "avaliacao": 4.8,
            "fornecedor": {
                "nome": "Dell",
                "pais": "Brasil"
            }
        },
        {
            "id": 2,
            "nome": "Mouse Sem Fio",
            "categoria": "Perifericos",
            "preco": 120.50,
            "estoque": 35,
            "avaliacao": 4.5,
            "fornecedor": {
                "nome": "Logitech",
                "pais": "Suica"
            }
        },
        {
            "id": 3,
            "nome": "Teclado Mecânico",
            "categoria": "Perifericos",
            "preco": 350.00,
            "estoque": 20,
            "avaliacao": 4.7,
            "fornecedor": {
                "nome": "Redragon",
                "pais": "China"
            }
        },
        {
            "id": 4,
            "nome": "Monitor 27 Polegadas",
            "categoria": "Monitores",
            "preco": 1500.00,
            "estoque": 8,
            "avaliacao": 4.9,
            "fornecedor": {
                "nome": "Samsung",
                "pais": "Coreia do Sul"
            }
        }
    ],
    "vendas": [
        {
            "pedido_id": 1001,
            "cliente": "Carlos",
            "produto_id": 1,
            "quantidade": 1,
            "valor_total": 4500.90,
            "forma_pagamento": "Cartao"
        },
        {
            "pedido_id": 1002,
            "cliente": "Ana",
            "produto_id": 2,
            "quantidade": 2,
            "valor_total": 241.00,
            "forma_pagamento": "Pix"
        },
        {
            "pedido_id": 1003,
            "cliente": "Marina",
            "produto_id": 4,
            "quantidade": 1,
            "valor_total": 1500.00,
            "forma_pagamento": "Boleto"
        }
    ]
}

# %%
with open("exercicios/dadosVendas.json", "w", encoding="utf8") as file:
    json.dump(dados, file, ensure_ascii=False, indent=3)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 with open("exercicios/dadosVendas.json", "w", encoding="utf8") as file:
#       2     json.dump(dados, file, ensure_ascii=False, indent=3)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'exercicios/dadosVendas.json'
